# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np

# %%
path="/content/drive/MyDrive/Python Course/NumPy and Pandas/books.csv"
data=pd.read_csv(path)

# %%
data.shape
# Out:
# (5000, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               5000 non-null   object
#  1   author              5000 non-null   object
#  2   average_rating      5000 non-null   float64
#  3   isbn13              5000 non-null   int64
#  4   language_code       4923 non-null   object
#  5   num_pages           4967 non-null   float64
#  6   ratings_count       5000 non-null   int64
#  7   text_reviews_count  5000 non-null   int64
#  8   publisher           5000 non-null   object
#  9   year                5000 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 390.8+ KB

# %%
data['num_pages'].describe()
# Out:
# count    4967.000000
# mean      341.094021
# std       230.986115
# min         1.000000
# 25%       200.000000
# 50%       304.000000
# 75%       416.500000
# max      3342.000000
# Name: num_pages, dtype: float64

# %%
new = data[data['average_rating']>4]
new
# Out:
#                                                   title  \
# 1     La Cucina Di Lidia: Recipes and Memories from ...
# 4     The Killing Dance (Anita Blake  Vampire Hunter...
# 5          The Hand of Chaos (The Death Gate Cycle  #5)
# 6                                       On Intelligence
# 11                        Merlin's Tour of the Universe
# ...                                                 ...
# 4991                                       'Salem's Lot
# 4992                  A Mad People's History of Madness
# 4993     A Christmas Carol (Great Illustrated Classics)
# 4995                                 The Complete Works
# 4999  The Avignon Quintet: Monsieur  Livia  Constanc...
#
#                            author  average_rating         isbn13  \
# 1     Lidia Matticchio Bastianich            4.14  9780767914222
# 4             Laurell K. Hamilton            4.13  9780425209066
# 5                   Margaret Weis            4.06  9780553563696
# ...

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2115 entries, 1 to 4999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               2115 non-null   object
#  1   author              2115 non-null   object
#  2   average_rating      2115 non-null   float64
#  3   isbn13              2115 non-null   int64
#  4   language_code       2072 non-null   object
#  5   num_pages           2103 non-null   float64
#  6   ratings_count       2115 non-null   int64
#  7   text_reviews_count  2115 non-null   int64
#  8   publisher           2115 non-null   object
#  9   year                2115 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 181.8+ KB

# %%
new2 = data[(data['average_rating']>4)&(data['ratings_count']<10)]
new2
# Out:
#                                                   title  \
# 14                                    On Vital Reserves
# 48           The Dark Descent  Vol 1: The Color of Evil
# 53    La Emperatriz tras el velo (Trilogía Taj Mahal...
# 63                                             鋼之鍊金術師 9
# 75    Also sprach Zarathustra: Ein Buch für Alle und...
# ...                                                 ...
# 4843                      Thucydides  Book 6 Commentary
# 4917                          Taxation of Mineral Rents
# 4933  Oliver Wendell Holmes in Paris: Medicine  Theo...
# 4945                           The SFWA Grand Masters 3
# 4992                  A Mad People's History of Madness
#
#                       author  average_rating         isbn13 language_code  \
# 14            William  James            4.50  9780870611513           eng
# 48         David G. Hartwell            4.12  9780246136671           eng
# ...

# %%
new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 14 to 4992
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               107 non-null    object
#  1   author              107 non-null    object
#  2   average_rating      107 non-null    float64
#  3   isbn13              107 non-null    int64
#  4   language_code       95 non-null     object
#  5   num_pages           104 non-null    float64
#  6   ratings_count       107 non-null    int64
#  7   text_reviews_count  107 non-null    int64
#  8   publisher           107 non-null    object
#  9   year                107 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 9.2+ KB

# %%
data.groupby(['language_code'])['average_rating'].mean()
# Out:
# language_code
# en-GB    3.922523
# en-US    3.914800
# eng      3.931143
# ger      3.979773
# grc      2.366667
# jpn      4.252381
# lat      4.170000
# mul      4.116000
# spa      3.927938
# Name: average_rating, dtype: float64

# %%
data['num_pages'].mean()
# Out:
# 341.0940205355345

# %%
data['num_pages'].max()
# Out:
# 3342.0

# %%
data['num_pages'].mode()
# Out:
# 0    288.0
# Name: num_pages, dtype: float64

# %%
data['num_pages'].median()
# Out:
# 304.0

# %%
year2010=data[data['year']==2010]
year2010
# Out:
#                                                   title  \
# 40    The Walking Dead  Book One (The Walking Dead #...
# 359        Things: A Story of the Sixties; A Man Asleep
# 425   The Gap Into Vision: Forbidden Knowledge (Gap ...
# 985                                     Never Let Me Go
# 1696           The Unexpected Guest: A Play In Two Acts
# 1789  A Short History of Nearly Everything (Illustra...
# 2620                                         The Client
# 2695                                      Lord of Light
# 2706         Pimsleur German Level 1 CD: [Lessons 1-30]
# 3079                             Tim Burton: Interviews
# 3724                                     Less Than Zero
# 4460                                     Riddley Walker
# 4650  The Beatles' Story on Capitol Records  Part Tw...
# 4891   Judy Moody Declares Independence (Judy Moody #6)
# 4914  Earthquake in the Early Morning (Magic Tree Ho...
#
# ...

# %%
year2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 40 to 4914
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               15 non-null     object
#  1   author              15 non-null     object
#  2   average_rating      15 non-null     float64
#  3   isbn13              15 non-null     int64
#  4   language_code       15 non-null     object
#  5   num_pages           15 non-null     float64
#  6   ratings_count       15 non-null     int64
#  7   text_reviews_count  15 non-null     int64
#  8   publisher           15 non-null     object
#  9   year                15 non-null     int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 1.3+ KB

# %%
new3 = data[(data['average_rating']>4)&(data['publisher']=='DAW')]
new3
# Out:
#                                                title           author  \
# 71                           By the Sword (Valdemar)  Mercedes Lackey
# 871         Storm Rising (Valdemar: Mage Storms  #2)  Mercedes Lackey
# 1523       Phoenix and Ashes (Elemental Masters  #3)  Mercedes Lackey
# 1583  To Battle the Gods (Jalav  Amazon Warrior  #5)     Sharon Green
# 3726        Oathblood (Valdemar: Vows and Honor  #3)  Mercedes Lackey
# 4367                     Joust (Dragon Jousters  #1)  Mercedes Lackey
#
#       average_rating         isbn13 language_code  num_pages  ratings_count  \
# 71              4.25  9780886774639           eng      492.0          18531
# 871             4.02  9780886777128         en-US      412.0          10781
# 1523            4.01  9780756402723           eng      480.0           6980
# 1583            4.07  9780886771287           eng      446.0             87
# 3726            4.06  9780886777739         en-GB      394.0           9786
# ...

# %%
new3['author'].unique()
# Out:
# array(['Mercedes Lackey', 'Sharon Green'], dtype=object)

# %%
new4 = data[(data['year']>2010)&(data['num_pages']>500)]
new4
# Out:
#                                                   title               author  \
# 2045  Billy Budd  Sailor and Other Uncompleted Writi...      Herman Melville
# 2775          Rick Steves' Europe Through the Back Door          Rick Steves
# 3075                                          The Iliad                Homer
# 3157                    George Washington's Sacred Fire    Peter A. Lillback
# 3546                                  The Will to Power  Friedrich Nietzsche
#
#       average_rating         isbn13 language_code  num_pages  ratings_count  \
# 2045            3.11  9780810111141           eng     1016.0              0
# 2775            4.24  9781566918084           eng      808.0           3569
# 3075            3.86  9781904633389           eng      542.0             64
# 3157            4.18  9780978605261           eng     1200.0            694
# 3546            4.05  9780394704371           eng      575.0           7931
#
# ...

# %%
new4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 2045 to 3546
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               5 non-null      object
#  1   author              5 non-null      object
#  2   average_rating      5 non-null      float64
#  3   isbn13              5 non-null      int64
#  4   language_code       5 non-null      object
#  5   num_pages           5 non-null      float64
#  6   ratings_count       5 non-null      int64
#  7   text_reviews_count  5 non-null      int64
#  8   publisher           5 non-null      object
#  9   year                5 non-null      int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 440.0+ bytes

# %%
new5 = data[data['author']== 'Agatha Christie']
new5
# Out:
#                                                   title           author  \
# 809      One  Two  Buckle My Shoe (Hercule Poirot  #23)  Agatha Christie
# 850             A Murder Is Announced (Miss Marple  #5)  Agatha Christie
# 865     The Listerdale Mystery And Eleven Other Stories  Agatha Christie
# 969             Death on the Nile (Hercule Poirot  #17)  Agatha Christie
# 1021           Cards on the Table (Hercule Poirot  #15)  Agatha Christie
# 1396                           And Then There Were None  Agatha Christie
# 1433             Hallowe'en Party (Hercule Poirot  #39)  Agatha Christie
# 1448         Hickory Dickory Dock (Hercule Poirot  #32)  Agatha Christie
# 1696           The Unexpected Guest: A Play In Two Acts  Agatha Christie
# 2041      The Labours of Hercules (Hercule Poirot  #27)  Agatha Christie
# 2322                 Sleeping Murder (Miss Marple  #13)  Agatha Christie
# 2598           Evil Under the Sun (Hercule Poirot  #24)  Agatha Christie
# ...

# %%
new5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 809 to 4894
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               21 non-null     object
#  1   author              21 non-null     object
#  2   average_rating      21 non-null     float64
#  3   isbn13              21 non-null     int64
#  4   language_code       21 non-null     object
#  5   num_pages           19 non-null     float64
#  6   ratings_count       21 non-null     int64
#  7   text_reviews_count  21 non-null     int64
#  8   publisher           21 non-null     object
#  9   year                21 non-null     int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 1.8+ KB

# %%
new6 = data[(data['year']>2000)&(data['language_code']=='spa')]
new6
# Out:
#                                                   title  \
# 21                      Los funerales de la Mamá Grande
# 53    La Emperatriz tras el velo (Trilogía Taj Mahal...
# 69                             La casa de los espíritus
# 93                                  Ya Sé Que Te Quiero
# 107                                 Secretos De Familia
# ...                                                 ...
# 4804                                      Muerte Blanca
# 4832  Entrevista con el vampiro (Crónicas vampíricas...
# 4890         Isabel: Princesa De Castilla  España  1466
# 4907                                     Ve  perro ¡Ve!
# 4951                                El librero de Kabul
#
#                       author  average_rating         isbn13 language_code  \
# 21    Gabriel García Márquez            3.78  9780307350329           spa
# 53           Indu Sundaresan            4.04  9788425337604           spa
# ...

# %%
new6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 21 to 4951
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               84 non-null     object
#  1   author              84 non-null     object
#  2   average_rating      84 non-null     float64
#  3   isbn13              84 non-null     int64
#  4   language_code       84 non-null     object
#  5   num_pages           83 non-null     float64
#  6   ratings_count       84 non-null     int64
#  7   text_reviews_count  84 non-null     int64
#  8   publisher           84 non-null     object
#  9   year                84 non-null     int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 7.2+ KB
