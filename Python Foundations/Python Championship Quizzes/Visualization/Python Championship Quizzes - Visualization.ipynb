# %%
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# to restrict the float value to 3 decimal places
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
data = pd.read_csv('/content/drive/MyDrive/Python Course/Python Championship Quizzes/Visualization/prog_book.csv')

# %%
data.head()
# Out:
#    Rating Reviews                                         Book_title  \
# 0    4.17   3,829                              The Elements of Style
# 1    4.01   1,406      The Information: A History, a Theory, a Flood
# 2    3.33       0       Responsive Web Design Overview For Beginners
# 3    3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4    4.06   1,325                                   How Google Works
#
#                                          Description  Number_Of_Pages  \
# 0  This style manual offers practical advice on i...              105
# 1  James Gleick, the author of the best sellers C...              527
# 2  In Responsive Web Design Overview For Beginner...               50
# 3  If they were a hall of fame or shame for compu...              393
# 4  Both Eric Schmidt and Jonathan Rosenberg came ...              305
#
#              Type      Price
# 0       Hardcover   9.323529
# 1       Hardcover  11.000000
# 2  Kindle Edition  11.267647
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rating           271 non-null    float64
#  1   Reviews          271 non-null    object
#  2   Book_title       271 non-null    object
#  3   Description      271 non-null    object
#  4   Number_Of_Pages  271 non-null    int64
#  5   Type             271 non-null    object
#  6   Price            271 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 14.9+ KB

# %%
data.describe()
# Out:
#            Rating  Number_Of_Pages       Price
# count  271.000000       271.000000  271.000000
# mean     4.067417       475.077491   54.541860
# std      0.290749       306.147492   35.711485
# min      3.000000        50.000000    9.323529
# 25%      3.915000       289.000000   30.751471
# 50%      4.100000       384.000000   46.317647
# 75%      4.250000       572.500000   67.854412
# max      5.000000      3168.000000  235.650000

# %%
data.describe(include= 'all')
# Out:
#             Rating Reviews             Book_title  \
# count   271.000000     271                    271
# unique         NaN     133                    271
# top            NaN       0  The Elements of Style
# freq           NaN      22                      1
# mean      4.067417     NaN                    NaN
# std       0.290749     NaN                    NaN
# min       3.000000     NaN                    NaN
# 25%       3.915000     NaN                    NaN
# 50%       4.100000     NaN                    NaN
# 75%       4.250000     NaN                    NaN
# max       5.000000     NaN                    NaN
#
#                                               Description  Number_Of_Pages  \
# count                                                 271       271.000000
# unique                                                270              NaN
# top     Learn You a Haskell for Great Good! is a fun, ...              NaN
# ...

# %%
data['Rating'].value_counts()
# Out:
# 4.150    9
# 4.110    8
# 4.230    7
# 4.000    7
# 4.250    7
#         ..
# 3.380    1
# 3.600    1
# 4.430    1
# 4.390    1
# 4.770    1
# Name: Rating, Length: 94, dtype: int64

# %%
Paperback_Data = data[data['Type']=='Paperback']
Paperback_Data
# Out:
#      Rating Reviews                                         Book_title  \
# 5     3.840     117                                   The Meme Machine
# 9     4.620       0  ZX Spectrum Games Code Club: Twenty fun games ...
# 12    3.730      33                                           Ship It!
# 16    3.850      80  The Quark and the Jaguar: Adventures in the Si...
# 17    3.940     279  Linked: How Everything Is Connected to Everyth...
# ..      ...     ...                                                ...
# 246   4.370       0  A First Course in Logic: An Introduction to Mo...
# 250   4.100      31     Computer Architecture: A Quantitative Approach
# 253   4.110      56              Modern Operating Systems, 4th Edition
# 257   3.870      13  File Structures: An Object-Oriented Approach w...
# 267   3.940      22                An Introduction to Database Systems
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
Paperback_Data[data['Rating']==Paperback_Data['Rating'].max()]
# Out:
# <ipython-input-18-593af68f932c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Paperback_Data[data['Rating']==Paperback_Data['Rating'].max()]
#      Rating Reviews                                         Book_title  \
# 131   4.720     362  Designing Data-Intensive Applications: The Big...
#
#                                            Description  Number_Of_Pages  \
# 131  Want to know how the best software engineers a...              616
#
#           Type  Price
# 131  Paperback 45.562

# %%
Price_Above_150 = data[data['Price']>150]
Price_Above_150
# Out:
#      Rating Reviews                                         Book_title  \
# 265   4.260       5  Numerical Recipes: The Art of Scientific Compu...
# 266   3.760       0  3D Game Engine Architecture: Engineering Real-...
# 267   3.940      22                An Introduction to Database Systems
# 268   4.490      36  The Art of Computer Programming, Volumes 1-3 B...
# 269   4.770       4  The Art of Computer Programming, Volumes 1-4a ...
# 270   3.840       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# 265  Co-authored by four leading scientists from ac...             1235
# 266  Dave Eberly's 3D Game Engine Design was the fi...              752
# 267  Continuing in the eighth edition, An Introduct...             1040
# 268  Knuth's classic work has been widely acclaimed...              896
# 269  "The bible of all fundamental algorithms and t...             3168
# ...

# %%
sns.histplot(data=data,x='Price',kde=True)
plt.show()

# %%
sns.countplot(data=data,x='Type')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data=data,x='Rating',y='Type')
plt.show()

# %%
sns.stripplot(data=data,x='Type',y='Rating')
plt.xticks(rotation=90)
plt.show()

# %%
sns.jointplot(data=data, x="Price", y="Rating", kind="kde", fill=True);

# %%
sns.jointplot(data=data, x="Price", y="Number_Of_Pages");

# %%
data['Type'].value_counts()
# Out:
# Paperback                156
# Hardcover                 95
# Kindle Edition            10
# ebook                      7
# Unknown Binding            2
# Boxed Set - Hardcover      1
# Name: Type, dtype: int64

# %%
data['Rating'].value_counts()
# Out:
# 4.150    9
# 4.110    8
# 4.230    7
# 4.000    7
# 4.250    7
#         ..
# 3.380    1
# 3.600    1
# 4.430    1
# 4.390    1
# 4.770    1
# Name: Rating, Length: 94, dtype: int64

# %%
k = data[data['Type'] == 'Paperback']
k[k['Rating'] == k['Rating'].max()]
# Out:
#      Rating Reviews                                         Book_title  \
# 131   4.720     362  Designing Data-Intensive Applications: The Big...
#
#                                            Description  Number_Of_Pages  \
# 131  Want to know how the best software engineers a...              616
#
#           Type  Price
# 131  Paperback 45.562

# %%
k = data[data['Price'] > 150]
k['Type'].unique()
# Out:
# array(['Hardcover', 'Paperback', 'Boxed Set - Hardcover'], dtype=object)

# %%
sns.histplot(data["Price"], kde = True);

# %%
sns.countplot(x="Type", data=data);

# %%
sns.boxplot(data= data, x= "Rating", y= "Type");

# %%
sns.stripplot(data= data, x= "Type", y= "Rating");

# %%
sns.jointplot(data=data, x='Price', y='Rating', kind='kde', fill=True);

# %%
sns.jointplot(x = "Price", y = "Number_Of_Pages", kind = "scatter", data = data);
