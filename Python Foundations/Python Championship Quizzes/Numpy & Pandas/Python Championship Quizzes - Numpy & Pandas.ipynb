# %%
import numpy as np
import pandas as pd

# %%
a = ['x', 'y', 'z']
b = ['w']
a.append(b)
a
# Out:
# ['x', 'y', 'z', ['w']]

# %%
a = ('x', 'y', 'z')
a[0] = 't'
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8b8e83d489e6> in <cell line: 2>()
#       1 a = ('x', 'y', 'z')
# ----> 2 a[0] = 't'
#       3 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %%
data = pd.read_csv('/content/drive/MyDrive/Python Course/Python Championship Quizzes/Numpy & Pandas/Dateset_ODI.csv')

# %%
data.head()
# Out:
#   Scorecard       Team 1     Team 2       Winner     Margin        Ground  \
# 0   ODI # 1    Australia    England    Australia  5 wickets     Melbourne
# 1   ODI # 2      England  Australia      England  6 wickets    Manchester
# 2   ODI # 3      England  Australia    Australia  5 wickets        Lord's
# 3   ODI # 4      England  Australia      England  2 wickets    Birmingham
# 4   ODI # 5  New Zealand   Pakistan  New Zealand    22 runs  Christchurch
#
#      Match Date
# 0   Jan 5, 1971
# 1  Aug 24, 1972
# 2  Aug 26, 1972
# 3  Aug 28, 1972
# 4  Feb 11, 1973

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3932 entries, 0 to 3931
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Scorecard   3932 non-null   object
#  1   Team 1      3932 non-null   object
#  2   Team 2      3932 non-null   object
#  3   Winner      3932 non-null   object
#  4   Margin      3753 non-null   object
#  5   Ground      3932 non-null   object
#  6   Match Date  3932 non-null   object
# dtypes: object(7)
# memory usage: 215.2+ KB

# %%
data.describe()
# Out:
#        Scorecard     Team 1     Team 2     Winner     Margin   Ground  \
# count       3932       3932       3932       3932       3753     3932
# unique      3932         24         25         25        227      173
# top      ODI # 1  Australia  Sri Lanka  Australia  6 wickets  Sharjah
# freq           1        583        508        555        347      228
#
#          Match Date
# count          3932
# unique         3386
# top     Feb 4, 2007
# freq              6

# %%
Sharjah_Winners = data[data['Ground']== 'Sharjah']
Sharjah_Winners
# Out:
#        Scorecard       Team 1       Team 2       Winner      Margin   Ground  \
# 258    ODI # 259     Pakistan    Sri Lanka    Sri Lanka   5 wickets  Sharjah
# 259    ODI # 260        India    Sri Lanka        India  10 wickets  Sharjah
# 260    ODI # 261        India     Pakistan        India     54 runs  Sharjah
# 320    ODI # 321        India     Pakistan        India     38 runs  Sharjah
# 321    ODI # 322    Australia      England    Australia   2 wickets  Sharjah
# ...          ...          ...          ...          ...         ...      ...
# 3721  ODI # 3722  Afghanistan     Zimbabwe  Afghanistan   2 wickets  Sharjah
# 3783  ODI # 3784     Pakistan  West Indies     Pakistan    111 runs  Sharjah
# 3787  ODI # 3788     Pakistan  West Indies     Pakistan     59 runs  Sharjah
# 3926  ODI # 3927     Pakistan    Sri Lanka     Pakistan   7 wickets  Sharjah
# 3929  ODI # 3930     Pakistan    Sri Lanka     Pakistan   9 wickets  Sharjah
#
#         Match Date
# 258    Apr 6, 1984
# ...

# %%
Sharjah_Winners.describe()
# Out:
#         Scorecard    Team 1     Team 2    Winner     Margin   Ground  \
# count         228       228        228       228        226      228
# unique        228        10         14        13         91        1
# top     ODI # 259  Pakistan  Sri Lanka  Pakistan  7 wickets  Sharjah
# freq            1        72         62        83         20      228
#
#          Match Date
# count           228
# unique          228
# top     Apr 6, 1984
# freq              1

# %%
By_date = data.groupby('Match Date').count()
By_date
# Out:
#              Scorecard  Team 1  Team 2  Winner  Margin  Ground
# Match Date
# Apr 1, 1984          1       1       1       1       1       1
# Apr 1, 1988          1       1       1       1       1       1
# Apr 1, 1995          1       1       1       1       1       1
# Apr 1, 1996          1       1       1       1       0       1
# Apr 1, 1998          2       2       2       2       2       2
# ...                ...     ...     ...     ...     ...     ...
# Sep 9, 1986          1       1       1       1       1       1
# Sep 9, 1994          1       1       1       1       1       1
# Sep 9, 2003          1       1       1       1       1       1
# Sep 9, 2009          1       1       1       1       1       1
# Sep 9, 2011          1       1       1       1       1       1
#
# [3386 rows x 6 columns]

# %%
By_date[By_date['Scorecard']== 6]
# Out:
#              Scorecard  Team 1  Team 2  Winner  Margin  Ground
# Match Date
# Feb 4, 2007          6       6       6       6       6       6

# %%
Australi_Wins = data[data['Winner']== 'Australia']
Australi_Wins
# Out:
#        Scorecard       Team 1     Team 2     Winner     Margin        Ground  \
# 0        ODI # 1    Australia    England  Australia  5 wickets     Melbourne
# 2        ODI # 3      England  Australia  Australia  5 wickets        Lord's
# 9       ODI # 10  New Zealand  Australia  Australia  7 wickets       Dunedin
# 10      ODI # 11  New Zealand  Australia  Australia    31 runs  Christchurch
# 20      ODI # 21    Australia   Pakistan  Australia    73 runs         Leeds
# ...          ...          ...        ...        ...        ...           ...
# 3816  ODI # 3817    Australia   Pakistan  Australia    92 runs      Brisbane
# 3819  ODI # 3820    Australia   Pakistan  Australia  7 wickets         Perth
# 3821  ODI # 3822    Australia   Pakistan  Australia    86 runs        Sydney
# 3825  ODI # 3826    Australia   Pakistan  Australia    57 runs      Adelaide
# 3916  ODI # 3917        India  Australia  Australia    21 runs     Bengaluru
#
#         Match Date
# 0      Jan 5, 1971
# ...

# %%
Australi_Wins.describe()
# Out:
#        Scorecard     Team 1     Team 2     Winner     Margin  Ground  \
# count        555        555        555        555        555     555
# unique       555         14         19          1        151      97
# top      ODI # 1  Australia  Australia  Australia  7 wickets  Sydney
# freq           1        383        172        555         47      85
#
#          Match Date
# count           555
# unique          555
# top     Jan 5, 1971
# freq              1

# %%
Team2_Wins = data[data['Winner']== data['Team 2']]
Team2_Wins
# Out:
#        Scorecard       Team 1       Team 2       Winner     Margin  \
# 2        ODI # 3      England    Australia    Australia  5 wickets
# 8        ODI # 9      England  West Indies  West Indies  8 wickets
# 9       ODI # 10  New Zealand    Australia    Australia  7 wickets
# 10      ODI # 11  New Zealand    Australia    Australia    31 runs
# 13      ODI # 14      England     Pakistan     Pakistan  7 wickets
# ...          ...          ...          ...          ...        ...
# 3907  ODI # 3908    Sri Lanka        India        India   168 runs
# 3908  ODI # 3909    Sri Lanka        India        India  6 wickets
# 3916  ODI # 3917        India    Australia    Australia    21 runs
# 3919  ODI # 3920       P.N.G.     Scotland     Scotland   101 runs
# 3927  ODI # 3928        India  New Zealand  New Zealand  6 wickets
#
#              Ground    Match Date
# 2            Lord's  Aug 26, 1972
# 8          The Oval   Sep 7, 1973
# 9           Dunedin  Mar 30, 1974
# ...

# %%
Lords_Wins = data[data['Ground']== 'Lord\'s']
Lords_Wins
# Out:
#        Scorecard       Team 1        Team 2        Winner     Margin  Ground  \
# 2        ODI # 3      England     Australia     Australia  5 wickets  Lord's
# 18      ODI # 19      England         India       England   202 runs  Lord's
# 32      ODI # 33    Australia   West Indies   West Indies    17 runs  Lord's
# 37      ODI # 38      England   West Indies   West Indies    36 runs  Lord's
# 62      ODI # 63      England     Australia       England  6 wickets  Lord's
# 73      ODI # 74      England   West Indies   West Indies    92 runs  Lord's
# 89      ODI # 90      England   West Indies       England  3 wickets  Lord's
# 118    ODI # 119      England     Australia       England  6 wickets  Lord's
# 204    ODI # 205      England      Pakistan       England  8 wickets  Lord's
# 214    ODI # 215    Australia   West Indies   West Indies  7 wickets  Lord's
# 222    ODI # 223        India   West Indies         India    43 runs  Lord's
# ...

# %%
Lords_Wins.describe()
# Out:
#        Scorecard   Team 1     Team 2   Winner     Margin  Ground    Match Date
# count         60       60         60       60         57      60            60
# unique        60        4          9       10         31       1            60
# top      ODI # 3  England  Australia  England  7 wickets  Lord's  Aug 26, 1972
# freq           1       52         14       23         11      60             1

# %%
x = 1
for i in range(1,10,2):
   print(x*i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a = np.array([['m','2'],['n','3']])
print(a[0,1])
# Out:
# 2

# %%
data['Ground'].value_counts()
# Out:
# Sharjah       228
# Dhaka         156
# Sydney        154
# Melbourne     147
# Harare        136
#              ...
# Hove            1
# Nairobi         1
# Vijayawada      1
# Kwekwe          1
# Lucknow         1
# Name: Ground, Length: 173, dtype: int64

# %%
data1 = data[data['Ground'] == 'Sharjah']
data1['Winner'].value_counts()
# Out:
# Pakistan        83
# India           35
# Sri Lanka       29
# West Indies     19
# Australia       14
# South Africa    10
# New Zealand      9
# Afghanistan      9
# England          8
# Zimbabwe         8
# tied             2
# Canada           1
# Netherlands      1
# Name: Winner, dtype: int64

# %%
 data['Match Date'].value_counts()
# Out:
# Feb 4, 2007     6
# Jun 7, 1975     4
# Jul 10, 2010    4
# Jun 14, 1975    4
# Jun 11, 1975    4
#                ..
# Sep 26, 1998    1
# Sep 27, 1998    1
# Sep 30, 1998    1
# Oct 24, 1998    1
# Oct 29, 2017    1
# Name: Match Date, Length: 3386, dtype: int64

# %%
data1 = data[data['Winner'] == 'Australia']
data1['Ground'].value_counts()
# Out:
# Sydney        85
# Melbourne     74
# Adelaide      34
# Perth         29
# Brisbane      23
#               ..
# Cardiff        1
# Bristol        1
# Faridabad      1
# Amstelveen     1
# Benoni         1
# Name: Ground, Length: 97, dtype: int64

# %%
(data['Team 2'] == data['Winner']).sum()
# Out:
# 1637

# %%
data1 = data[data['Ground'] == "Lord's"]
data1['Winner'].value_counts()
# Out:
# England         23
# Australia       12
# West Indies      6
# India            4
# Pakistan         4
# Sri Lanka        4
# New Zealand      3
# tied             2
# no result        1
# South Africa     1
# Name: Winner, dtype: int64
